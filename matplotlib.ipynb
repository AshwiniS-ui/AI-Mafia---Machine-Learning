# %% [markdown]
# # Matplotlib Library!!

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3]
y = [2,4,1]

# %%
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.plot(x,y)
plt.title('condingclub')
x1 = [1,2plt.show()

# %%
x1 = [1,2,3]
y1 = [2,4,1]

x2 = [1,2,3]
y2 = [4,1,3]
plt.plot(x1,y1,label="line 1")
plt.plot(x2,y2,label="line 2")
plt.legend()
plt.show()

# %% [markdown]
# Customizing line plot.

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
x=[2,2,3,4,5,6]
y=[2,4,3,5,2,6]

# %%
plt.plot(x,y,color='green',linestyle='dashed',linewidth=3,marker='o',markerfacecolor='blue',markersize=8)

# %%
plt.ylim(1,8)
plt.xlim(1,8)
# Out:
# (1.0, 8.0)

# %% [markdown]
# # Bar charts

# %%
left = [1,2,3,4,5]

# %%
height = [10,24,36,40,5]

# %%
tick_label = ['one','two','three','four','five']

# %%
plt.bar(left,height,tick_label=tick_label,width=0.8,color=['red','blue'])
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# # Pie-Chart

# %%
activities = ['eat','sleep','work','play']

# %%
slices = [3,7,8,6]

# %%
colors = ['r','m','g','b']

# %%
plt.pie(slices,labels=activities,colors=colors,startangle=90,shadow=True,explode=(0,0,0.1,0),radius=1.2,autopct='%1.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x19eecec87f0>,
#   <matplotlib.patches.Wedge at 0x19eeced5160>,
#   <matplotlib.patches.Wedge at 0x19eeced5a30>,
#   <matplotlib.patches.Wedge at 0x19eecee4340>],
#  [Text(-0.5051421307219185, 1.2195209829148985, 'eat'),
#   Text(-1.3087072223905565, -0.17229453288713012, 'sleep'),
#   Text(0.709999961620642, -1.2297560955322349, 'work'),
#   Text(0.933380951166243, 0.9333809511662425, 'play')],
#  [Text(-0.2755320713028646, 0.6651932634081265, '12.5%'),
#   Text(-0.7138403031221217, -0.09397883612025279, '29.2%'),
#   Text(0.40999997783727216, -0.7101408438988961, '33.3%'),
#   Text(0.5091168824543143, 0.5091168824543141, '25.0%')])
